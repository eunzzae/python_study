# %%
# !pip install pyautogui
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.54.tar.gz (61 kB)
#      ---------------------------------------- 61.2/61.2 kB 1.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pytweening>=1.0.4
#   Downloading pytweening-1.0.7.tar.gz (168 kB)
#      -------------------------------------- 168.2/168.2 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.29.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyrect
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyscreenshot
#   Downloading pyscreenshot-3.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: Pillow>=9.2.0 in c:\programdata\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.4.0)
# Collecting pyperclip
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting EasyProcess
#   Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Collecting entrypoint2
#   Downloading entrypoint2-1.1-py2.py3-none-any.whl (9.9 kB)
# Collecting mss
#   Downloading mss-9.0.1-py3-none-any.whl (22 kB)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, pytweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (pyproject.toml): started
#   Building wheel for pyautogui (pyproject.toml): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.54-py3-none-any.whl size=37601 sha256=5e746c00a2c346ba3ddcf31e34d9f241bcc6d64e35079a5d66567e99fe4297ab
#   Stored in directory: c:\users\dmsco\appdata\local\pip\cache\wheels\27\ae\44\6ed17dd0eb2109b293dfd896e6b32176a662472e9ec276e911
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11079 sha256=d5d2cf0bc37acae038814a5e9f51fa0b756a607f92c5f0388ee5df25487c49f4
#   Stored in directory: c:\users\dmsco\appdata\local\pip\cache\wheels\b4\ba\41\c09cef95c23cdfed6af9df7328306fafbf27df2e77b14d25d7
#   Building wheel for pyscreeze (pyproject.toml): started
#   Building wheel for pyscreeze (pyproject.toml): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.29-py3-none-any.whl size=13485 sha256=594e901e590d540d7101c1211f65f1b594e7994912648ef238002fab509002f2
#   Stored in directory: c:\users\dmsco\appdata\local\pip\cache\wheels\b9\76\96\c84d250d637354da1dfd1a3c255b2df6e30c192354d08af1b8
#   Building wheel for pytweening (setup.py): started
#   Building wheel for pytweening (setup.py): finished with status 'done'
#   Created wheel for pytweening: filename=pytweening-1.0.7-py3-none-any.whl size=6214 sha256=bebde039ac89dd69f2d089b15306fb99627ed84669d3539ad8cf1e4ddf6b0272
#   Stored in directory: c:\users\dmsco\appdata\local\pip\cache\wheels\c6\4a\25\8e83858414a3d4f8d69cb04f86501b11160106b05fc9c8063b
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10906 sha256=b2b39226d6bcf481e7aa40599cfea404b7cb7b47bfda216abf131e3318bcbdd4
#   Stored in directory: c:\users\dmsco\appdata\local\pip\cache\wheels\52\e8\77\5f70ba97301c6d825754eea9f12f0ffd00e119fba64a68f4d2
#   Building wheel for pymsgbox (pyproject.toml): started
#   Building wheel for pymsgbox (pyproject.toml): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7417 sha256=abe64ea4d6888af7c479b89ca781eba31375e24fbecbe053d5127c50e9e51615
#   Stored in directory: c:\users\dmsco\appdata\local\pip\cache\wheels\97\61\22\1a0de2324b204d675c5bfb28b944101eb48dcf1a1fe87bcce7
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=c600175f44cdb54aba82c35778d95f825001146f0ee0d1aa15692a0fbce72125
#   Stored in directory: c:\users\dmsco\appdata\local\pip\cache\wheels\3c\77\81\aaa2802e9b0553585f2789c6f2756b50a09a01d2848423bb15
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11205 sha256=d9b9c6a30188e53cfefdaecbe280b05d11adb439e3577c06458dae8db0b3cdfc
#   Stored in directory: c:\users\dmsco\appdata\local\pip\cache\wheels\63\0e\55\adb1553ad973caacffc0bd779f74f4749f904da246674a26a1
# Successfully built pyautogui pygetwindow pyscreeze pytweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: pytweening, pyrect, pyperclip, pymsgbox, entrypoint2, EasyProcess, pygetwindow, mss, mouseinfo, pyscreenshot, pyscreeze, pyautogui
# Successfully installed EasyProcess-1.1 entrypoint2-1.1 mouseinfo-0.1.3 mss-9.0.1 pyautogui-0.9.54 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreenshot-3.1 pyscreeze-0.1.29 pytweening-1.0.7
#   WARNING: The script mss.exe is installed in 'C:\Users\dmsco\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pyautogui

# %% [markdown]
# ### 마우스 제어
# #### 화면과 마우스 위치
# * size()함수 : 모니터 해상도 크기 확인, 값은 튜플로 반환

# %%
pyautogui.size()
# Out:
# Size(width=1920, height=1080)

# %% [markdown]
# * position()함수 : 마우스 커서의 현재 X, Y좌표 반환

# %%
pyautogui.position()
# Out:
# Point(x=1114, y=779)

# %%
pyautogui.position()
# Out:
# Point(x=1576, y=390)

# %% [markdown]
# * moveTo()함수 : 마우스 커서가 지정한 X, Y좌표로 이동
# ex) pyautogui.moveTo(100,400,3) -> #마우스 커서가 X, Y좌표(100, 400)dmfh 3초 동안 이동

# %%
pyautogui.moveTo(100,200)

# %%
pyautogui.moveTo(100,400,3)

# %%
pyautogui.moveTo(0,200)
pyautogui.moveTo(100,200)
pyautogui.moveTo(100,200,3)

# %% [markdown]
# * dragTo()함수 : 드래그하는 기능
#     - button속성으로 left, right, middle(좌측, 우측, 휠버튼) 지정 가능

# %%
pyautogui.dragTo(500,500,button="left")
pyautogui.dragTo(300,300,2,button="left")
pyautogui.dragTo(100,0,2,button="left")

# %% [markdown]
# * click()함수 : 마우스 왼쪽 버튼을 한 번 클릭

# %%
pyautogui.click()

# %%
pyautogui.click(x=100,y=200)

# %%
pyautogui.click(button="right")

# %% [markdown]
# pyautogui.click(button="right", clicks=3, interval=0.25)
# -> #마우스 오른쪽 버튼을 0.25초 간격으로 3번 클릭

# %%
pyautogui.click(clicks=2)
pyautogui.click(clicks=2, interval=0.25)
pyautogui.click(button="right", clicks=3, interval=0.25)

# %%
pyautogui.doubleClick()
pyautogui.tripleClick()

# %%
pyautogui.mouseDown()
pyautogui.mouseUp()
pyautogui.mouseDown(button="right")
pyautogui.mouseUp(button="right", x=200,y=300)

# %%
pyautogui.scroll(10)
pyautogui.scroll(-15)
pyautogui.scroll(10,x=200,y=200)

# %% [markdown]
# ### 키보드 제어
# * write()함수 : 키보드로 전달되는 문자열 입력

# %%
pyautogui.write("Hello")
pyautogui.write("Good morning", interval=0.25)

# %%
HelloGood morning
# Out:
#   Cell In[22], line 1
#     HelloGood morning
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# * keyDown, Up() : 키보드의 키를 누르고 뗄 때 쓰는 함수
# * pressDown, Up() 동일

# %%
pyautogui.keyDown("shift")
pyautogui.keyUp("shift")

# %%
pyautogui.press("shift")

# %%
pyautogui.keyDown("shift")
pyautogui.press("left")
pyautogui.press("left")
pyautogui.press("left")
pyautogui.keyUp("shift")

# %%
pyautogui.press(["left","left","left"])

# %% [markdown]
# * hotkey()함수 : 윈도우의 단축키 사용

# %%
pyautogui.hotkey("ctrl","c")

# %% [markdown]
# ### 메시지 박스
# : 메시지를 표시하거나 승인 및 취소, 필요한 데이터 입력받는 등의 기능을 하는 대화상자 출력
# * alert()함수 : 확인버튼 하나 있는 간단한 메시지 박스를 표시

# %%
pyautogui.alert(text="alert 함수입니다.", title="alert 함수", button="OK")
# Out:
# 'OK'

# %% [markdown]
# * confirm()함수 : 확인 및 취소 버튼이 있는 메시지 박스 표시

# %%
pyautogui.confirm(text="confirm 함수입니다.", title="confirm 함수", buttons=["OK","Cancel"])
# Out:
# 'Cancel'

# %% [markdown]
# * prompt()함수 : 텍스트를 입력하고 ok 버튼을 누르면 입력한 텍스트를 반환, 취소 버튼을 누르면 none을 반환

# %%
pyautogui.prompt(text="prompt 함수입니다.", title="prompt 함수", default="ID")

# %% [markdown]
# * password()함수 : 입력한 문자가 *로 나타남

# %%
pyautogui.password(text="패스워드를 입력하세요.", title="로그인", mask="*")
# Out:
# '1651'

# %% [markdown]
# ### 스크린 샷
# * pillow 설치

# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (9.4.0)

# %%
from PIL import Image

# %% [markdown]
# * screenshot()함수 : 화면 전체 또는 일부 캡처 가능

# %%
image1=pyautogui.screenshot()
print(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x237E9CD53C0>

# %%
image2=pyautogui.screenshot("screenshot.png")

# %%
image3=pyautogui.screenshot(region=(0,0,300,400))
print(image3)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400 at 0x237EC216C20>

# %%
import matplotlib.pyplot as plt
plt.imshow(image3)

# %% [markdown]
# ### locateOnScreen() 함수
# **오류 반환** 원인 찾기

# %%
image3=pyautogui.locateOnScreen("image3")
image3
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 image3=pyautogui.locateOnScreen("image3")
#       2 image3
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyautogui\__init__.py:172, in raisePyAutoGUIImageNotFoundException.<locals>.wrapper(*args, **kwargs)
#     169 @functools.wraps(wrappedFunction)
#     170 def wrapper(*args, **kwargs):
#     171     try:
# --> 172         return wrappedFunction(*args, **kwargs)
#     173     except pyscreeze.ImageNotFoundException:
#     174         raise ImageNotFoundException
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyautogui\__init__.py:210, in locateOnScreen(*args, **kwargs)
#     208 @raisePyAutoGUIImageNotFoundException
#     209 def locateOnScreen(*args, **kwargs):
# --> 210     return pyscreeze.locateOnScreen(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyscreeze\__init__.py:378, in locateOnScreen(image, minSearchTime, **kwargs)
#     374 try:
#     375     screenshotIm = screenshot(
#     376         region=None
#     377     )  # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 378     retVal = locate(image, screenshotIm, **kwargs)
#     379     try:
#     380         screenshotIm.fp.close()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyscreeze\__init__.py:356, in locate(needleImage, haystackImage, **kwargs)
#     354 # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     355 kwargs['limit'] = 1
# --> 356 points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     357 if len(points) > 0:
#     358     return points[0]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pyscreeze\__init__.py:256, in _locateAll_pillow(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     253 needleFileObj = None
#     254 if isinstance(needleImage, (str, unicode)):
#     255     # 'image' is a filename, load the Image object
# --> 256     needleFileObj = open(needleImage, 'rb')
#     257     needleImage = Image.open(needleFileObj)
#     259 haystackFileObj = None
#
# FileNotFoundError: [Errno 2] No such file or directory: 'image3'

# %%
import pyautogui
import time
import datetime

# %%
str_cap_num=pyautogui.prompt(text="몇 번 캡처할지 입력해 주세요", title="캡처 횟수", default="")
int_cap_num=int(str_cap_num)

# %%
i=0
while i<int_cap_num:
    i=i+1

# %%
pyautogui.hotkey("win","s")
time.sleep(0.5)
pyautogui.write("snippingtool")
pyautogui.press("enter")
time.sleep(1)

# %%
snippingtool
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 snippingtool
#
# NameError: name 'snippingtool' is not defined

# %%
pyautogui.hotkey("alt","n")
time.sleep(1)

# %%
import pyautogui
import time
time.sleep(3)
pyautogui.position()
# Out:
# Point(x=1176, y=825)

# %%
import pyautogui
import time
time.sleep(3)
pyautogui.position()
# Out:
# Point(x=648, y=684)

# %%
import pyautogui
import time
time.sleep(3)
pyautogui.position()
# Out:
# Point(x=114, y=407)

# %%
pyautogui.moveTo(114,407)
pyautogui.dragTo(648,684, duration=2,button="left")
time.sleep(1)

# %% [markdown]
# # 복습

# %%
# !pip install pyautogui
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyautogui in c:\users\dmsco\appdata\roaming\python\python310\site-packages (0.9.54)
# Requirement already satisfied: pymsgbox in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: mouseinfo in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyautogui) (0.1.29)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: pyrect in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: Pillow>=9.2.0 in c:\programdata\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.4.0)
# Requirement already satisfied: pyscreenshot in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyscreeze>=0.1.21->pyautogui) (3.1)
# Requirement already satisfied: pyperclip in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: mss in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (9.0.1)
# Requirement already satisfied: entrypoint2 in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: EasyProcess in c:\users\dmsco\appdata\roaming\python\python310\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)

# %%
import pyautogui

# %%
pyautogui.size()
# Out:
# Size(width=1920, height=1080)

# %%
pyautogui.position()
# Out:
# Point(x=491, y=803)

# %%
pyautogui.moveTo(100,200)

# %%
pyautogui.moveTo(300,500,3)

# %%
pyautogui.move(0,200)
pyautogui.move(300,200)
pyautogui.move(100,200,1)

# %%
pyautogui.dragTo(500,500,button="left")

# %%
pyautogui.dragTo(400,900,2,button="left")

# %%
pyautogui.drag(100,600,2,button="right")

# %%
pyautogui.click()

# %%
pyautogui.click(x=500,y=300)

# %%
pyautogui.click(button="right")

# %%
pyautogui.click(clicks=2)

# %%
pyautogui.click(clicks=2,interval=0.25)

# %%
pyautogui.click(button="right",clicks=3,interval=0.25)

# %%
pyautogui.doubleClick()

# %%
pyautogui.tripleClick()

# %%
pyautogui.mouseDown
# Out:
# <function pyautogui.mouseDown(x=None, y=None, button='primary', duration=0.0, tween=<function linear at 0x00000183F90183A0>, logScreenshot=None, _pause=True)>

# %%
pyautogui.mouseUp
# Out:
# <function pyautogui.mouseUp(x=None, y=None, button='primary', duration=0.0, tween=<function linear at 0x00000183F90183A0>, logScreenshot=None, _pause=True)>

# %%
pyautogui.scroll(10)

# %%
pyautogui.scroll(-15)

# %%
pyautogui.scroll(10,x=100,y=200)

# %%
pyautogui.write("Hello")

# %%
pyautogui.write("Good morning", interval=0.25)

# %%
Good morning
# Out:
#   Cell In[28], line 1
#     Good morning
#          ^
# SyntaxError: invalid syntax

# %%
pyautogui.keyDown("shift")

# %%
pyautogui.keyUp("shift")

# %%
pyautogui.press("shift")

# %%
pyautogui.keyDown("shift")
pyautogui.press("left")
pyautogui.press("left")
pyautogui.press("left")
pyautogui.keyUp("shift")

# %%
pyautogui.press(["left","left","left"])

# %%
pyautogui.hotkey("ctrl","c")

# %%
pyautogui.keyDown("ctrl")
pyautogui.press("c")
pyautogui.keyUp("ctrl")

# %%
pyautogui.alert(text="alert 함수입니다.", title="alert 함수", button="OK")
# Out:
# 'OK'

# %%
pyautogui.confirm(text="confirm 함수입니다.", title="confirm 함수", buttons=["OK","Cancel"])
# Out:
# 'Cancel'

# %%
pyautogui.prompt(text="prompt 함수입니다.", title="prompt 함수", default="ID")
# Out:
# 'ebrhda'

# %%
pyautogui.password(text="패스워드를 입력하세요.", title="로그인",mask="*")
# Out:
# 'ebrhdaj'

# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (9.4.0)

# %%
from PIL import Image

# %%
image1=pyautogui.screenshot()
print(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x183FC774160>

# %%
image2=pyautogui.screenshot("screenshot.png")

# %%
image3=pyautogui.screenshot(region=(0,0,300,400))
print(image3)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400 at 0x183F901C3A0>

# %%
import matplotlib.pyplot as plt
plt.imshow(image3)

# %%
plt.imshow(image2)

# %%
image4=pyautogui.screenshot(region=(200,100,1200,800))

# %%
plt.imshow(image4)

# %%
cal_key_location.left
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 cal_key_location.left
#
# NameError: name 'cal_key_location' is not defined
